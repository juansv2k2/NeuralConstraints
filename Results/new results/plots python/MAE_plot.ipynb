# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data lists
data1 = [
    0.48791, 0.975420, 1.191910, 1.025080, 1.098670, 1.048120, 1.358650, 0.890390, 0.967340, 0.900770, 1.038570, 
    1.072830, 0.785650, 0.864020, 0.897040, 0.975420, 1.191910, 1.025080, 1.098670, 1.048120, 1.358650, 0.890390, 
    1.078450, 1.004390, 0.960740, 0.745140, 0.792710, 1.175240, 1.161600, 1.151150, 1.115270, 1.038120, 1.040670, 
    1.294560, 0.895020, 1.203130, 0.972770, 0.978850, 1.146240, 1.130980, 0.911390, 0.978810, 1.053650, 0.946630, 
    1.017000, 0.852940, 1.016440, 0.927970, 1.072490, 0.934930, 1.130260, 1.005010, 1.044050, 0.966960, 0.968340, 
    0.905510, 0.916800, 1.015730, 1.034360, 1.056270, 0.944860, 0.873340, 0.860330, 0.878570, 0.811510, 0.885380, 
    1.137910, 0.956380, 0.902120, 0.755940, 0.964550, 0.886550, 0.892380, 0.770250, 0.920180, 0.967800, 0.686470, 
    0.883180, 0.888000, 0.934830, 0.904250, 1.030910, 0.841210, 0.908430, 0.770790, 0.941510, 1.062200, 0.798990, 
    0.832650, 0.999630, 1.177430, 1.172220, 0.953410, 1.075420
]

data2 = [ 0.3863, 0.870680, 1.167290, 0.901420, 0.987550, 0.733110, 0.668860, 0.809340, 0.726430, 0.859710, 0.951570, 0.941870, 0.919800, 1.192370, 1.031560, 0.861090, 1.231590, 1.160680, 0.891850, 0.818360, 1.268160, 0.994650, 1.011220, 1.108040, 0.840340, 1.206530, 1.131240, 1.010760, 0.881290, 1.125460, 0.946370, 0.901600, 1.165850, 0.898900, 1.117240, 1.125700, 0.908690, 0.947350, 0.974870, 0.953400, 0.833110, 0.850990, 1.106140, 1.210010, 1.156750, 0.929530, 0.794910, 1.062950, 1.001370, 0.922000, 1.147750, 0.868850, 1.093230, 0.743740, 1.157160, 0.912410, 0.911480, 1.086740, 0.739490, 0.844210, 0.993980, 1.094940, 0.981020, 0.766730, 1.116160, 0.837690, 0.735050, 0.890770, 1.030580, 1.259470, 0.915460, 1.012230, 1.225290, 1.016330, 1.080240, 0.767540, 0.969260, 0.724430, 1.015830, 1.041230, 1.034880, 1.060120, 1.023960, 1.051520, 0.875360, 1.076730, 0.880150, 0.866620, 1.097810, 1.122230, 0.948780, 0.981000, 0.917610, 1.070150 ]

# Generate index positions
x1 = np.arange(len(data1))
x2 = np.arange(len(data2))

# Compute best-fit lines
coeff1 = np.polyfit(x1, data1, 1)
coeff2 = np.polyfit(x2, data2, 1)

fit1 = np.poly1d(coeff1)
fit2 = np.poly1d(coeff2)

# Plotting
fig, axs = plt.subplots(2, 1, figsize=(10, 8), sharex=True)

# Graph for data1
axs[0].scatter(x1, data1, color='blue', s=10, label='Data 1 Points')
axs[0].plot(x1, fit1(x1), color='red', linewidth=2, label='Best Fit Line')
axs[0].set_title('Graph of Data 1')
axs[0].set_ylabel('Values')
axs[0].legend()
axs[0].grid(True)

# Graph for data2
axs[1].scatter(x2, data2, color='green', s=10, label='Data 2 Points')
axs[1].plot(x2, fit2(x2), color='orange', linewidth=2, label='Best Fit Line')
axs[1].set_title('Graph of Data 2')
axs[1].set_xlabel('Index')
axs[1].set_ylabel('Values')
axs[1].legend()
axs[1].grid(True)

plt.tight_layout()
plt.show()

# %%
# Lists of values
list1 = [
    0.0809, 0.013940, 0.007300, 0.019600, 0.020990, 0.028040, 0.031070,
    0.032910, 0.268940, 0.018780, 0.028370, 0.022210, 0.011520, 0.043090,
    0.080900, 0.013940, 0.007300, 0.019600, 0.020990, 0.028040, 0.275690,
    0.115510, 0.053300, 0.013280, 0.027550, 0.019060, 0.036760, 0.012090,
    0.203690, 0.026270, 0.012130, 0.009530, 0.021110, 0.026620, 0.009740,
    0.022820, 0.010180, 0.015550, 0.027260, 0.028980, 0.007420, 0.017630,
    0.011410, 0.110840, 0.008220, 0.021090, 0.011760, 0.017680, 0.144390,
    0.033650, 0.295460, 0.225650, 0.196770, 0.215630, 0.187490, 0.113720,
    0.117840, 0.193540, 0.261730, 0.236650, 0.182410, 0.216040, 0.460390,
    0.030750, 0.065970, 0.022000, 0.016340, 0.277640, 0.044540, 0.035730,
    0.072180, 0.053010, 0.044540, 0.012700, 0.022550, 0.015680, 0.055360,
    0.013890, 0.023050, 0.026350, 0.005900, 0.030340, 0.031800, 0.016270,
    0.142380, 0.012640, 0.126780, 0.027550, 0.021270, 0.026210, 0.402120,
    0.218150, 0.180490, 0.567000
]
list2 = [
    0.7244, 1.399440, 0.547290, 0.591460, 1.080740, 0.919310, 1.378140,
    1.587830, 0.697690, 0.906590, 0.762170, 0.488460, 1.344820, 0.562990,
    1.060240, 1.776790, 1.055290, 0.677450, 1.056370, 0.555200, 0.882940,
    1.016530, 0.967440, 1.111280, 0.970010, 0.487020, 1.266310, 0.400840,
    0.699800, 0.974800, 1.558280, 0.836380, 1.231320, 0.871020, 1.235640,
    1.020790, 1.570240, 1.222450, 0.830410, 1.141310, 0.242490, 0.561520,
    1.295240, 0.317080, 1.360700, 0.724170, 1.169050, 0.336330, 1.331330,
    1.378440, 0.361840, 1.378920, 0.388190, 1.130530, 1.224980, 1.202380,
    0.851770, 1.506030, 1.097120, 0.424190, 0.882920, 0.849670, 0.304450,
    1.561250, 0.780140, 0.493620, 1.197570, 0.552180, 0.832830, 1.479130,
    0.302000, 0.463570, 0.774690, 0.432900, 0.901180, 1.644580, 1.150650,
    0.730940, 1.400250, 1.110170, 0.341360, 0.335930, 0.216250, 0.393920,
    0.124420, 1.634160, 0.744140, 0.812460, 0.915080, 0.700580, 1.444260,
    0.545570, 1.223330, 0.812750
]

# Calculate mean and standard deviation
mean_list1 = np.mean(list1)
std_list1 = np.std(list1)
mean_list2 = np.mean(list2)
std_list2 = np.std(list2)

# Bar plot
categories = ['List 1', 'List 2']
means = [mean_list1, mean_list2]
std_devs = [std_list1, std_list2]

plt.bar(categories, means, yerr=std_devs, capsize=5, color=['skyblue', 'salmon'], alpha=0.7)
plt.ylabel('Mean Value')
plt.title('Mean and Standard Deviation of Two Lists')
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.show()

# %%
# Creating the time series plot with more spacing between points
plt.figure(figsize=(10, 6))
plt.plot(list1, label='Sequence 1 (NN)', color='blue', marker='o', linestyle='-', alpha=0.7, markersize=5)
plt.plot(list2, label='Sequence 2 (no NN)', color='red', marker='x', linestyle='-', alpha=0.7, markersize=5)

# Adding labels, title, and grid
plt.xlabel('Index', fontsize=12)
plt.ylabel('MAE Value', fontsize=12)
plt.title('MAE of Sequences 1 and 2', fontsize=14)
plt.xticks(ticks=range(0, len(list1), 5), fontsize=10)  # Adding spacing to x-axis ticks
plt.legend(fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)

# Displaying the plot
plt.tight_layout()
plt.show()
